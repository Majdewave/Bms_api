# %% [markdown]
# # 1. Update Appointment Entity
# Add `Guid? ServiceId` and `Guid? StaffId` properties to the Appointment entity. Add navigation properties: `BusinessService? Service` and `Staff? Staff`. Do not remove existing fields.

# %% [markdown]
# # 2. Update DTOs
# Add `Guid? ServiceId` and `Guid? StaffId` to `CreateAppointmentRequest` and `UpdateAppointmentRequest` DTOs. Do not change existing fields.

# %% [markdown]
# # 3. Update AppointmentResponse Record
# Modify the `AppointmentResponse` record constructor to include `Guid? ServiceId` and `Guid? StaffId` as parameters, preserving all existing fields.

# %% [markdown]
# # 4. Modify AppointmentsController
# In `Create()` and `Update()`, set `appointment.ServiceId = request.ServiceId` and `appointment.StaffId = request.StaffId`. In `GetAll()` and `GetById()`, add `.Include(a => a.Service)` and `.Include(a => a.Staff)`. Return `ServiceId` and `StaffId` in `AppointmentResponse`.

# %% [markdown]
# # 5. Update AppDbContext Mappings
# Ensure EF Core maps Appointments to Service (BusinessService) and Staff entities. Update relationships if needed.

# %% [markdown]
# # 6. Generate EF Migration: AddStaffAndServiceToAppointments
# Run EF Core migration command to generate `AddStaffAndServiceToAppointments` migration reflecting the new fields and relationships.
